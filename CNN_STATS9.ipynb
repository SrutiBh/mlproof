# %%
# %load_ext autoreload
# %autoreload 2

import nolearn.lasagne.visualize 

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is disabled, CuDNN 4007)
# /home/d/nolearn/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
from stats import Stats
# Out:
# mlproof/tifffile.py:1995: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# mlproof/tifffile.py:1995: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# mlproof/tifffile.py:1995: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)

# %%
cnn1 = '/home/d/nets/MergeNetDropout_cylinder1_border_overlap_dropout_usevars/net.p'
cnn2 = '/home/d/nets/MergeNetDropout_cylinder1_larger_border_overlap_dropout_usevars/net.p'
cnn3 = '/home/d/nets/MergeNetThreeLegDropout_cylinder1_larger_border_overlap_dropout_usevars/net.p'
cnn4 = '/home/d/nets/MergeNetDropout_cylinder1_border_overlap_dropout_usevars_LargerDropout/net.p'
cnn5 = '/home/d/nets/MergeNetDropout_cylinder1_larger_border_overlap_dropout_usevars_LargerDropout/net.p'
cnn6 = '/home/d/nets/MergeNetThreeLeg_LargerDropout/net.p'
cnn7 = '/home/d/nets/RGBANet_cylinder1_rgba_border_overlap_dropout_usevars/net.p'
cnn8 = '/home/d/nets/RGBANet_cylinder1_rgba_larger_border_overlap_dropout_usevars/net.p'
cnn9 = '/home/d/nets/RGBNet_cylinder1_rgba_larger_border_overlap_dropout_usevars/net.p'

cnn = Stats.load_cnn(cnn9)
# Out:
# Loaded /home/d/patches//cylinder1_rgba/ in 0.000468015670776 seconds.
#
# Precision/Recall:
#              precision    recall  f1-score   support
#
#           0       0.90      0.89      0.90     13408
#           1       0.89      0.90      0.90     13408
#
# avg / total       0.90      0.90      0.90     26816
#
# Test Accuracy: 0.896703460621
# Accuracy Score: 0.896703460621
# /home/d/nolearn/local/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
nolearn.lasagne.visualize.draw_to_notebook(cnn)

# %%
Stats.run_dojo_xp(cnn)
# Out:
# Finding Top 5 merge errors..
# 11  merge errors found.
# Creating dojo bigM..
#
# Correcting merge errors with p < .05
#    Mean VI improvement 0.00380480408836
#    Median VI improvement 0.0
# Correcting split errors with p > .95
#    Mean VI improvement -0.172939611813
#    Median VI improvement -0.149104438616
#
# Correcting merge errors with p < .01
#    Mean VI improvement 0.00380480408836
#    Median VI improvement 0.0
# Correcting split errors with p > .99
#    Mean VI improvement -0.104212435465
#    Median VI improvement -0.0828890487878
#
# Correcting merge errors by simulated user (er=0)
#    Mean VI improvement 0.00455910830222
#    Median VI improvement 0.0
# Correcting split errors by simulated user (er=0)
#    Mean VI improvement 0.111899426019
#    Median VI improvement 0.0893631771544
#
#    Re-running simulated user with er=0 .. 0.2

# %%
Stats.run_cylinder_xp(cnn)
# Out:
# Creating cylinder bigM..
# 6252 generated in 379.47991395 seconds.
# Grouped into 1533 patches in 0.0302350521088 seconds.
# 5820 generated in 370.505290985 seconds.
# Grouped into 1422 patches in 0.0289649963379 seconds.
# 6368 generated in 411.863759041 seconds.
# Grouped into 1572 patches in 0.0318491458893 seconds.
# 5692 generated in 364.564388037 seconds.
# Grouped into 1402 patches in 0.0271129608154 seconds.
# 5460 generated in 350.661170959 seconds.
# Grouped into 1339 patches in 0.0230848789215 seconds.
# 5404 generated in 538.330108881 seconds.
# Grouped into 1313 patches in 0.0260429382324 seconds.
# 5724 generated in 2390.55478692 seconds.
# Grouped into 1393 patches in 0.026978969574 seconds.
# 5524 generated in 395.174099922 seconds.
# Grouped into 1353 patches in 0.0260338783264 seconds.
# 5348 generated in 390.706866026 seconds.
# Grouped into 1304 patches in 0.025778055191 seconds.
# 5332 generated in 400.410764933 seconds.
# Grouped into 1299 patches in 0.0255520343781 seconds.
# 5240 generated in 357.94314909 seconds.
# Grouped into 1274 patches in 0.0248849391937 seconds.
# 4836 generated in 389.976998806 seconds.
# Grouped into 1185 patches in 0.0228478908539 seconds.
# 4840 generated in 302.663126945 seconds.
# Grouped into 1185 patches in 0.0224950313568 seconds.
# 4600 generated in 283.852138996 seconds.
# Grouped into 1131 patches in 0.0212869644165 seconds.
# 4548 generated in 282.061424971 seconds.
# Grouped into 1114 patches in 0.0204181671143 seconds.
# 4012 generated in 248.157817125 seconds.
# Grouped into 985 patches in 0.0182058811188 seconds.
# 3820 generated in 235.962858915 seconds.
# Grouped into 938 patches in 0.0167059898376 seconds.
# 3680 generated in 228.832886934 seconds.
# Grouped into 907 patches in 0.0172951221466 seconds.
# 3620 generated in 225.42355299 seconds.
# Grouped into 889 patches in 0.0167369842529 seconds.
# 3488 generated in 219.40546298 seconds.
# Grouped into 864 patches in 0.0160388946533 seconds.
# 3104 generated in 192.612018108 seconds.
# Grouped into 764 patches in 0.014585018158 seconds.
# 3032 generated in 188.750947952 seconds.
# Grouped into 741 patches in 0.013612985611 seconds.
# 2824 generated in 177.143332005 seconds.
# Grouped into 688 patches in 0.0131390094757 seconds.
# 2700 generated in 168.041770935 seconds.
# Grouped into 670 patches in 0.0126202106476 seconds.
# 2484 generated in 154.890014172 seconds.
# Grouped into 608 patches in 0.0110487937927 seconds.
# 2160 generated in 136.448904991 seconds.
# Grouped into 533 patches in 0.0103840827942 seconds.
# 2020 generated in 127.853892088 seconds.
# Grouped into 501 patches in 0.00945091247559 seconds.
# 2020 generated in 127.172092915 seconds.
# Grouped into 501 patches in 0.0103430747986 seconds.
# 1988 generated in 124.820230961 seconds.
# Grouped into 496 patches in 0.00937509536743 seconds.
# 2032 generated in 129.242261887 seconds.
# Grouped into 506 patches in 0.00947690010071 seconds.
# 1644 generated in 107.301528931 seconds.
# Grouped into 409 patches in 0.00743412971497 seconds.
# 1384 generated in 89.0432400703 seconds.
# Grouped into 341 patches in 0.00671100616455 seconds.
# 1348 generated in 89.898594141 seconds.
# Grouped into 334 patches in 0.00624394416809 seconds.
# 1144 generated in 77.2210950851 seconds.
# Grouped into 283 patches in 0.00548505783081 seconds.
# 1148 generated in 79.401362896 seconds.
# Grouped into 285 patches in 0.00515604019165 seconds.
# 1080 generated in 74.6939809322 seconds.
# Grouped into 270 patches in 0.00442695617676 seconds.
# 880 generated in 64.210119009 seconds.
# Grouped into 219 patches in 0.00417113304138 seconds.
# 884 generated in 64.9803061485 seconds.
# Grouped into 221 patches in 0.00425601005554 seconds.
# 932 generated in 67.2611730099 seconds.
# Grouped into 233 patches in 0.00421595573425 seconds.
# 804 generated in 58.360708952 seconds.
# Grouped into 201 patches in 0.00394582748413 seconds.
# 700 generated in 49.6010758877 seconds.
# Grouped into 174 patches in 0.00324392318726 seconds.
# 628 generated in 45.8096458912 seconds.
# Grouped into 157 patches in 0.00310611724854 seconds.
# 476 generated in 37.4464170933 seconds.
# Grouped into 119 patches in 0.00225400924683 seconds.
# 388 generated in 32.1869380474 seconds.
# Grouped into 97 patches in 0.00184988975525 seconds.
# 320 generated in 26.4013369083 seconds.
# Grouped into 80 patches in 0.00161099433899 seconds.
# 252 generated in 21.5387718678 seconds.
# Grouped into 63 patches in 0.00134801864624 seconds.
# 200 generated in 17.8269338608 seconds.
# Grouped into 50 patches in 0.00114798545837 seconds.
# 72 generated in 8.16004300117 seconds.
# Grouped into 18 patches in 0.000404119491577 seconds.
# 4 generated in 4.84426498413 seconds.
# Grouped into 1 patches in 7.31945037842e-05 seconds.
# 0 generated in 0.0849599838257 seconds.
# Grouped into 0 patches in 2.40802764893e-05 seconds.
#
# Correcting split errors with p > .95
# 30 minutes done bigM_max= 1.0
# 60 minutes done bigM_max= 1.0
# 90 minutes done bigM_max= 0.999999642372
# 120 minutes done bigM_max= 0.999995470047
# 150 minutes done bigM_max= 0.999973893166
# 180 minutes done bigM_max= 0.999879360199
# 210 minutes done bigM_max= 0.999627351761
# 240 minutes done bigM_max= 0.99894040823
# 270 minutes done bigM_max= 0.997502744198
# 300 minutes done bigM_max= 0.99466085434
# 330 minutes done bigM_max= 0.989454388618
# 360 minutes done bigM_max= 0.981534302235
# 390 minutes done bigM_max= 0.965057969093
#    Mean VI improvement 0.0281674381672
#    Median VI improvement 0.0282506373152
#
# Correcting split errors with p > .99
# 30 minutes done bigM_max= 1.0
# 60 minutes done bigM_max= 1.0
# 90 minutes done bigM_max= 0.999999642372
# 120 minutes done bigM_max= 0.999995470047
# 150 minutes done bigM_max= 0.999973893166
# 180 minutes done bigM_max= 0.999879360199
# 210 minutes done bigM_max= 0.999627351761
# 240 minutes done bigM_max= 0.99894040823
# 270 minutes done bigM_max= 0.997502744198
# 300 minutes done bigM_max= 0.99466085434
#    Mean VI improvement 0.0320483868777
#    Median VI improvement 0.0294104082228
#
# Correcting split errors by simulated user (er=0)
#    Mean VI improvement 0.0901153612113
#    Median VI improvement 0.0897923332062
