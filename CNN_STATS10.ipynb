# %%
# %load_ext autoreload
# %autoreload 2

import nolearn.lasagne.visualize 

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is disabled, CuDNN 4007)
# /home/d/nolearn/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
from stats import Stats
# Out:
# mlproof/tifffile.py:1995: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# mlproof/tifffile.py:1995: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# mlproof/tifffile.py:1995: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)

# %%
cnn1 = '/home/d/nets/MergeNetDropout_cylinder1_border_overlap_dropout_usevars/net.p'
cnn2 = '/home/d/nets/MergeNetDropout_cylinder1_larger_border_overlap_dropout_usevars/net.p'
cnn3 = '/home/d/nets/MergeNetThreeLegDropout_cylinder1_larger_border_overlap_dropout_usevars/net.p'
cnn4 = '/home/d/nets/MergeNetDropout_cylinder1_border_overlap_dropout_usevars_LargerDropout/net.p'
cnn5 = '/home/d/nets/MergeNetDropout_cylinder1_larger_border_overlap_dropout_usevars_LargerDropout/net.p'
cnn6 = '/home/d/nets/MergeNetThreeLeg_LargerDropout/net.p'
cnn7 = '/home/d/nets/RGBANet_cylinder1_rgba_border_overlap_dropout_usevars/net.p'
cnn8 = '/home/d/nets/RGBANet_cylinder1_rgba_larger_border_overlap_dropout_usevars/net.p'
cnn9 = '/home/d/nets/RGBNet_cylinder1_rgba_larger_border_overlap_dropout_usevars/net.p'
cnn10 = '/home/d/nets/RGBNetDropout_cylinder1_rgba_larger_border_overlap_dropout2_usevars/net.p'
cnn11 = '/home/d/nets/RGBANetDropout_cylinder1_rgba_larger_border_overlap_dropout2_usevars/net.p'

cnn = Stats.load_cnn(cnn10)
# Out:
# Loaded /home/d/patches//cylinder1_rgba/ in 0.000329971313477 seconds.
#
# Precision/Recall:
#              precision    recall  f1-score   support
#
#           0       0.89      0.90      0.90     13408
#           1       0.90      0.89      0.89     13408
#
# avg / total       0.89      0.89      0.89     26816
#
# Test Accuracy: 0.894838902148
# Accuracy Score: 0.894838902148
# /home/d/nolearn/local/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
nolearn.lasagne.visualize.draw_to_notebook(cnn)

# %%
Stats.run_dojo_xp(cnn)
# Out:
# Loading merge errors from file..
# 10  merge errors found.
# Loading dojo bigM from file..
#
# Loading merge errors p < .05 and split errors p > .95 from file..
#    Mean VI improvement -0.139140212807
#    Median VI improvement -0.126065545377
#
# Loading merge errors p < .01 and split errors p > .99 from file..
#    Mean VI improvement -0.0797538995223
#    Median VI improvement -0.0333072355832
#
# Loading merge errors and split errors (simulated user) from file..
#    Mean VI improvement 0.101557982316
#    Median VI improvement 0.0821859948159
#
# Loading merge errors and split errors (simulated user) with error rates from file..

# %%
Stats.run_cylinder_xp(cnn)
# Out:
# Creating cylinder bigM..
# 6252 generated in 357.252669096 seconds.
# Grouped into 1533 patches in 0.0288701057434 seconds.
# 5820 generated in 363.249014139 seconds.
# Grouped into 1422 patches in 0.0245289802551 seconds.
# 6368 generated in 395.31792593 seconds.
# Grouped into 1572 patches in 0.0290679931641 seconds.
# 5692 generated in 359.346869946 seconds.
# Grouped into 1402 patches in 0.0250091552734 seconds.
# 5460 generated in 341.904462099 seconds.
# Grouped into 1339 patches in 0.0229830741882 seconds.
# 5404 generated in 337.371845961 seconds.
# Grouped into 1313 patches in 0.0231790542603 seconds.
# 5724 generated in 346.390950918 seconds.
# Grouped into 1393 patches in 0.0262928009033 seconds.
# 5524 generated in 343.990302801 seconds.
# Grouped into 1353 patches in 0.0252771377563 seconds.
# 5348 generated in 328.927438974 seconds.
# Grouped into 1304 patches in 0.0237650871277 seconds.
# 5332 generated in 328.747452974 seconds.
# Grouped into 1299 patches in 0.0219700336456 seconds.
# 5240 generated in 380.75433588 seconds.
# Grouped into 1274 patches in 0.0240879058838 seconds.
# 4836 generated in 604.538477898 seconds.
# Grouped into 1185 patches in 0.0221629142761 seconds.
# 4840 generated in 571.822132826 seconds.
# Grouped into 1185 patches in 0.0211579799652 seconds.
# 4600 generated in 421.750633001 seconds.
# Grouped into 1131 patches in 0.0200259685516 seconds.
# 4548 generated in 279.435911894 seconds.
# Grouped into 1114 patches in 0.0201869010925 seconds.
# 4012 generated in 248.065948963 seconds.
# Grouped into 985 patches in 0.018532037735 seconds.
# 3820 generated in 232.053488016 seconds.
# Grouped into 938 patches in 0.0173029899597 seconds.
# 3680 generated in 229.444494009 seconds.
# Grouped into 907 patches in 0.0168919563293 seconds.
# 3620 generated in 223.652647972 seconds.
# Grouped into 889 patches in 0.016294002533 seconds.
# 3488 generated in 215.740019083 seconds.
# Grouped into 864 patches in 0.0157790184021 seconds.
# 3104 generated in 191.174953938 seconds.
# Grouped into 764 patches in 0.0143928527832 seconds.
# 3032 generated in 185.617128849 seconds.
# Grouped into 741 patches in 0.0137300491333 seconds.
# 2824 generated in 175.946862936 seconds.
# Grouped into 688 patches in 0.0129499435425 seconds.
# 2700 generated in 170.13460207 seconds.
# Grouped into 670 patches in 0.011244058609 seconds.
# 2484 generated in 155.018147945 seconds.
# Grouped into 608 patches in 0.0111238956451 seconds.
# 2160 generated in 136.904487848 seconds.
# Grouped into 533 patches in 0.00954794883728 seconds.
# 2020 generated in 128.378839016 seconds.
# Grouped into 501 patches in 0.0088369846344 seconds.
# 2020 generated in 125.737094879 seconds.
# Grouped into 501 patches in 0.00924897193909 seconds.
# 1988 generated in 125.515577078 seconds.
# Grouped into 496 patches in 0.00907897949219 seconds.
# 2032 generated in 128.186154127 seconds.
# Grouped into 506 patches in 0.00836396217346 seconds.
# 1644 generated in 107.695003033 seconds.
# Grouped into 409 patches in 0.00757884979248 seconds.
# 1384 generated in 89.8642308712 seconds.
# Grouped into 341 patches in 0.00621390342712 seconds.
# 1348 generated in 88.8216609955 seconds.
# Grouped into 334 patches in 0.0061469078064 seconds.
# 1144 generated in 77.2704119682 seconds.
# Grouped into 283 patches in 0.00512790679932 seconds.
# 1148 generated in 78.997387886 seconds.
# Grouped into 285 patches in 0.00479888916016 seconds.
# 1080 generated in 73.4005467892 seconds.
# Grouped into 270 patches in 0.00505518913269 seconds.
# 880 generated in 64.4720380306 seconds.
# Grouped into 219 patches in 0.00421714782715 seconds.
# 884 generated in 63.3318891525 seconds.
# Grouped into 221 patches in 0.00417900085449 seconds.
# 932 generated in 66.3206429482 seconds.
# Grouped into 233 patches in 0.00457406044006 seconds.
# 804 generated in 57.6888439655 seconds.
# Grouped into 201 patches in 0.00361394882202 seconds.
# 700 generated in 49.2086789608 seconds.
# Grouped into 174 patches in 0.00316095352173 seconds.
# 628 generated in 45.6828579903 seconds.
# Grouped into 157 patches in 0.00285911560059 seconds.
# 476 generated in 37.2572791576 seconds.
# Grouped into 119 patches in 0.00226998329163 seconds.
# 388 generated in 31.2788028717 seconds.
# Grouped into 97 patches in 0.00177001953125 seconds.
# 320 generated in 26.7176880836 seconds.
# Grouped into 80 patches in 0.00157618522644 seconds.
# 252 generated in 21.7633399963 seconds.
# Grouped into 63 patches in 0.00132989883423 seconds.
# 200 generated in 17.5937469006 seconds.
# Grouped into 50 patches in 0.00100612640381 seconds.
# 72 generated in 8.4134221077 seconds.
# Grouped into 18 patches in 0.000386953353882 seconds.
# 4 generated in 4.69434595108 seconds.
# Grouped into 1 patches in 6.79492950439e-05 seconds.
# 0 generated in 0.0874860286713 seconds.
# Grouped into 0 patches in 2.50339508057e-05 seconds.
#
# Correcting split errors with p > .95
# 30 minutes done bigM_max= 0.999999642372
# 60 minutes done bigM_max= 0.999992847443
# 90 minutes done bigM_max= 0.999960064888
# 120 minutes done bigM_max= 0.999879002571
# 150 minutes done bigM_max= 0.999673545361
# 180 minutes done bigM_max= 0.999255478382
# 210 minutes done bigM_max= 0.998571634293
# 240 minutes done bigM_max= 0.997225940228
# 270 minutes done bigM_max= 0.995114922523
# 300 minutes done bigM_max= 0.991328537464
# 330 minutes done bigM_max= 0.999939918518
# 360 minutes done bigM_max= 0.976283192635
# 390 minutes done bigM_max= 0.960772335529
#    Mean VI improvement 0.032837990725
#    Median VI improvement 0.0400389264039
#
# Correcting split errors with p > .99
# 30 minutes done bigM_max= 0.999999642372
# 60 minutes done bigM_max= 0.999992847443
# 90 minutes done bigM_max= 0.999960064888
# 120 minutes done bigM_max= 0.999879002571
# 150 minutes done bigM_max= 0.999673545361
# 180 minutes done bigM_max= 0.999255478382
# 210 minutes done bigM_max= 0.998571634293
# 240 minutes done bigM_max= 0.997225940228
# 270 minutes done bigM_max= 0.995114922523
# 300 minutes done bigM_max= 0.991328537464
#    Mean VI improvement 0.0309722029328
#    Median VI improvement 0.0360182424011
#
# Correcting split errors by simulated user (er=0)
#    Mean VI improvement 0.0909134726309
#    Median VI improvement 0.0903012195981
