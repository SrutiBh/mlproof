# %%
# %load_ext autoreload
# %autoreload 2

import nolearn.lasagne.visualize 

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is disabled, CuDNN 4007)
# /home/d/nolearn/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
from stats import Stats
# Out:
# mlproof/tifffile.py:1995: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# mlproof/tifffile.py:1995: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# mlproof/tifffile.py:1995: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)

# %%
cnn1 = '/home/d/nets/MergeNetDropout_cylinder1_border_overlap_dropout_usevars/net.p'
cnn2 = '/home/d/nets/MergeNetDropout_cylinder1_larger_border_overlap_dropout_usevars/net.p'
cnn3 = '/home/d/nets/MergeNetThreeLegDropout_cylinder1_larger_border_overlap_dropout_usevars/net.p'
cnn4 = '/home/d/nets/MergeNetDropout_cylinder1_border_overlap_dropout_usevars_LargerDropout/net.p'
cnn5 = '/home/d/nets/MergeNetDropout_cylinder1_larger_border_overlap_dropout_usevars_LargerDropout/net.p'
cnn6 = '/home/d/nets/MergeNetThreeLeg_LargerDropout/net.p'

cnn = Stats.load_cnn(cnn4)
# Out:
# Loaded /home/d/patches//cylinder1/ in 0.00157690048218 seconds.
# Using test set: ['image', 'prob', 'merged_array', 'border_overlap']
#
# Precision/Recall:
#              precision    recall  f1-score   support
#
#           0       0.92      0.90      0.91     13408
#           1       0.90      0.92      0.91     13408
#
# avg / total       0.91      0.91      0.91     26816
#
# Test Accuracy: 0.910948687351
# Accuracy Score: 0.910948687351
# /home/d/nolearn/local/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
nolearn.lasagne.visualize.draw_to_notebook(cnn)

# %%
Stats.run_dojo_xp(cnn)
# Out:
# Loading merge errors from file..
# 15  merge errors found.
# Loading dojo bigM from file..
#
# Loading merge errors p < .05 and split errors p > .95 from file..
#    Mean VI improvement 0.0187840496459
#    Median VI improvement 0.0192815319968
#
# Loading merge errors p < .01 and split errors p > .99 from file..
#    Mean VI improvement 0.0418440149599
#    Median VI improvement 0.0446248594244
#
# Loading merge errors and split errors (simulated user) from file..
#    Mean VI improvement 0.106924354474
#    Median VI improvement 0.0766142777644
#
# Loading merge errors and split errors (simulated user) with error rates from file..

# %%
fixes, vis = Stats.run_cylinder_xp(cnn)
# Out:
# Original median VI 0.484747666805
# Creating cylinder bigM..
# 6252 generated in 376.832605839 seconds.
# Grouped into 1533 patches in 0.0294399261475 seconds.
# 5820 generated in 374.001688957 seconds.
# Grouped into 1422 patches in 0.0234780311584 seconds.
# 6368 generated in 404.456186056 seconds.
# Grouped into 1572 patches in 0.0275480747223 seconds.
# 5692 generated in 369.074412107 seconds.
# Grouped into 1402 patches in 0.0276639461517 seconds.
# 5460 generated in 355.152778864 seconds.
# Grouped into 1339 patches in 0.0254189968109 seconds.
# 5404 generated in 348.089634895 seconds.
# Grouped into 1313 patches in 0.025946855545 seconds.
# 5724 generated in 356.887539864 seconds.
# Grouped into 1393 patches in 0.0265278816223 seconds.
# 5524 generated in 356.746383905 seconds.
# Grouped into 1353 patches in 0.0260200500488 seconds.
# 5348 generated in 341.938504934 seconds.
# Grouped into 1304 patches in 0.0258917808533 seconds.
# 5332 generated in 341.762649775 seconds.
# Grouped into 1299 patches in 0.0226211547852 seconds.
# 5240 generated in 334.714100122 seconds.
# Grouped into 1274 patches in 0.0235040187836 seconds.
# 4836 generated in 311.502490044 seconds.
# Grouped into 1185 patches in 0.0209178924561 seconds.
# 4840 generated in 311.036818027 seconds.
# Grouped into 1185 patches in 0.0212230682373 seconds.
# 4600 generated in 294.896216869 seconds.
# Grouped into 1131 patches in 0.0217509269714 seconds.
# 4548 generated in 292.894448996 seconds.
# Grouped into 1114 patches in 0.02099609375 seconds.
# 4012 generated in 258.943638086 seconds.
# Grouped into 985 patches in 0.016254901886 seconds.
# 3820 generated in 247.903259039 seconds.
# Grouped into 938 patches in 0.0161719322205 seconds.
# 3680 generated in 237.648005009 seconds.
# Grouped into 907 patches in 0.0175800323486 seconds.
# 3620 generated in 235.416281223 seconds.
# Grouped into 889 patches in 0.0167050361633 seconds.
# 3488 generated in 225.448276043 seconds.
# Grouped into 864 patches in 0.0162110328674 seconds.
# 3104 generated in 199.579513073 seconds.
# Grouped into 764 patches in 0.0145008563995 seconds.
# 3032 generated in 196.008038044 seconds.
# Grouped into 741 patches in 0.0139710903168 seconds.
# 2824 generated in 183.344418049 seconds.
# Grouped into 688 patches in 0.013081073761 seconds.
# 2700 generated in 177.125409126 seconds.
# Grouped into 670 patches in 0.772579908371 seconds.
# 2484 generated in 161.944638014 seconds.
# Grouped into 608 patches in 0.0115418434143 seconds.
# 2160 generated in 144.313516855 seconds.
# Grouped into 533 patches in 0.0100619792938 seconds.
# 2020 generated in 132.320770979 seconds.
# Grouped into 501 patches in 0.00945782661438 seconds.
# 2020 generated in 130.804126024 seconds.
# Grouped into 501 patches in 0.00901985168457 seconds.
# 1988 generated in 128.800821781 seconds.
# Grouped into 496 patches in 0.00924801826477 seconds.
# 2032 generated in 132.344251871 seconds.
# Grouped into 506 patches in 0.00961112976074 seconds.
# 1644 generated in 111.831714153 seconds.
# Grouped into 409 patches in 0.00748896598816 seconds.
# 1384 generated in 91.9937498569 seconds.
# Grouped into 341 patches in 0.00620198249817 seconds.
# 1348 generated in 91.6866180897 seconds.
# Grouped into 334 patches in 0.00612306594849 seconds.
# 1144 generated in 81.0383369923 seconds.
# Grouped into 283 patches in 0.00549101829529 seconds.
# 1148 generated in 79.7725508213 seconds.
# Grouped into 285 patches in 0.00530815124512 seconds.
# 1080 generated in 76.8461692333 seconds.
# Grouped into 270 patches in 0.00496983528137 seconds.
# 880 generated in 67.1503789425 seconds.
# Grouped into 219 patches in 0.0040819644928 seconds.
# 884 generated in 66.6161198616 seconds.
# Grouped into 221 patches in 0.00415301322937 seconds.
# 932 generated in 67.5719151497 seconds.
# Grouped into 233 patches in 0.00424790382385 seconds.
# 804 generated in 60.0300779343 seconds.
# Grouped into 201 patches in 0.00388717651367 seconds.
# 700 generated in 52.550989151 seconds.
# Grouped into 174 patches in 0.00320792198181 seconds.
# 628 generated in 46.7592988014 seconds.
# Grouped into 157 patches in 0.00282716751099 seconds.
# 476 generated in 38.4621291161 seconds.
# Grouped into 119 patches in 0.00226211547852 seconds.
# 388 generated in 32.5273861885 seconds.
# Grouped into 97 patches in 0.00190901756287 seconds.
# 320 generated in 27.762401104 seconds.
# Grouped into 80 patches in 0.00169706344604 seconds.
# 252 generated in 22.5819790363 seconds.
# Grouped into 63 patches in 0.0012059211731 seconds.
# 200 generated in 18.4565470219 seconds.
# Grouped into 50 patches in 0.000998020172119 seconds.
# 72 generated in 8.79240393639 seconds.
# Grouped into 18 patches in 0.000391006469727 seconds.
# 4 generated in 5.04957890511 seconds.
# Grouped into 1 patches in 7.29560852051e-05 seconds.
# 0 generated in 0.101883888245 seconds.
# Grouped into 0 patches in 2.50339508057e-05 seconds.
#
# Correcting split errors with p > .95
# 30 minutes done bigM_max= 0.999997138977
# 60 minutes done bigM_max= 0.999968409538
# 90 minutes done bigM_max= 0.999992370605
# 120 minutes done bigM_max= 0.999456465244
# 150 minutes done bigM_max= 0.998622059822
# 180 minutes done bigM_max= 0.997368097305
# 210 minutes done bigM_max= 0.995267093182
# 240 minutes done bigM_max= 0.991571426392
# 270 minutes done bigM_max= 0.985983729362
# 300 minutes done bigM_max= 0.978693842888
# 330 minutes done bigM_max= 0.968405127525
# 360 minutes done bigM_max= 0.952601969242
#    Mean VI improvement 0.0410001036359
#    Median VI improvement 0.0506394567255
#
# Correcting split errors with p > .99
# 30 minutes done bigM_max= 0.999997138977
# 60 minutes done bigM_max= 0.999968409538
# 90 minutes done bigM_max= 0.999992370605
# 120 minutes done bigM_max= 0.999456465244
# 150 minutes done bigM_max= 0.998622059822
# 180 minutes done bigM_max= 0.997368097305
# 210 minutes done bigM_max= 0.995267093182
# 240 minutes done bigM_max= 0.991571426392
#    Mean VI improvement 0.0374432228296
#    Median VI improvement 0.041928642291
#
# Correcting split errors by simulated user (er=0)
#    Mean VI improvement 0.0908955759385
#    Median VI improvement 0.0904133428987
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-668d0b28746d> in <module>()
# ----> 1 fixes, vis = Stats.run_cylinder_xp(cnn)
#
# TypeError: 'NoneType' object is not iterable
