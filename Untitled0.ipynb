# %%
# %load_ext autoreload
# %autoreload 2


import mahotas as mh
import numpy as np

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline

import mlproof as mlp

# %%
image, mask, gold, rhoana = mlp.Util.read_section('/home/d/data/cylinder/',0)

# %%
imshow(image)

# %%
imshow(gold)

# %%
imshow(mask)
